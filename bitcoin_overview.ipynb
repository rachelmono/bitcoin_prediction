# %% [markdown]
# # Introduction
#
# This project bitcoin is done for the 2020 UCLA data science bootcamp hackathon. We aim to use the tools and knowledge we learn understand the behavior of the most popular crytocurrency bitcoin and see if we can come up with an educated prediction of its price trend in the immediate and further future.
#
# In this notebook, we are using data from the Fred api https://fred.stlouisfed.org/ to try to get an overview of what are the factors that associate with bitcoin's price index over the years and generate a few hypothesis to work on.
#
# Bitcoin is not a stock or bond, it does not have a balance sheet. It is also not a currency that is issued by a bank or backed by a government. Ideally, bitcoin would only flutuates with its supply and demand, and its internal governance.
#
# In the following chapters, we take a look at bitcoin's price index over the years and compare it with other ecomonic and market index accessible in the Fed' database and see if we can make some senese of what that means.

# %%
import pandas as pd
import numpy as np
import datapungi_fed as dpf
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Download Data from FED API

# %%
bit = pd.read_csv('CBBTCUSD')

# %%
coinbase_idx = dpf('CBCCIND')
ethereum = dpf('CBETHUSD')
litecoin = dpf('CBLTCUSD')

# %% [markdown]
# ## coinbase index fund, ethereum, litecoin

# %%
bit.head()
# Out:
#             CBBTCUSD
# date
# 2014-12-01     370.0
# 2014-12-02     378.0
# 2014-12-03     378.0
# 2014-12-04     377.1
# 2014-12-06     378.0

# %%
# the data covers 2012 to current day and daily unjusted prices
bit.index.min(), bit.index.max()
# Out:
# (Timestamp('2014-12-01 00:00:00'), Timestamp('2020-05-08 00:00:00'))

# %% [markdown]
# Units:  U.S. Dollars, Not Seasonally Adjusted
#
# Frequency:  Daily, 7-Day
#
# All data is as of 5 PM PST.
#
# Copyright, 2018, Coinbase.
#
# Reproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.
# Suggested Citation:
#
# Coinbase, Coinbase Bitcoin [CBBTCUSD], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/CBBTCUSD, May 2, 2020.

# %%
# bit is a one column data frame
type(bit), bit.shape
# Out:
# (pandas.core.frame.DataFrame, (1946, 1))

# %%
plt.figure(figsize = (20, 8))
sns.lineplot(data = bit)
sns.lineplot(data = coinbase_idx, palette=['purple'])
sns.lineplot(data = ethereum, palette=['blue'])
sns.lineplot(data = coinbase_idx, palette=['grey'])
sns.lineplot(data = litecoin, palette=['black'])
plt.grid()
#plt.axvline('2020-1', alpha = 0.6, linestyle = '--', color = 'r')
plt.xticks(rotation=45)
# Out:
# (array([735234., 735599., 735964., 736330., 736695., 737060., 737425.]),
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# # The Bitcoin Price USD with other Economic Indicators

# %% [markdown]
# ## Monthly US Umemployment, Consumer Index, Federal Funds, and More

# %%
# monthly unemployment rate
unrate = dpf('UNRATE')

# %%
unrate = unrate.loc['2014-12-01':]

# %%
unrate.head()
# Out:
#             UNRATE
# date
# 2014-12-01     5.6
# 2015-01-01     5.7
# 2015-02-01     5.5
# 2015-03-01     5.4
# 2015-04-01     5.4

# %%
bit_monthly = bit.resample('MS').first() # sample the first day price to staty consistent with the other data format

# %%
unrate.index.min(), unrate.index.max()
# Out:
# (Timestamp('2014-12-01 00:00:00'), Timestamp('2020-03-01 00:00:00'))

# %%
bit_monthly.index.min(), bit_monthly.index.max()
# Out:
# (Timestamp('2014-12-31 00:00:00'), Timestamp('2020-05-31 00:00:00'))

# %%
pce = dpf('PCE')
fedfund = dpf('FEDFUNDS')
cpi = dpf('CUSR0000SEHE')

# %%
pce = pce.loc['2014-12-01':]
fedfund  = fedfund .loc['2014-12-01':]
cpi = cpi.loc['2014-12-01':]

# %%
bit_monthly = bit_monthly.join(unrate, how = 'outer')
bit_monthly = bit_monthly.join(pce, how = 'outer')
bit_monthly = bit_monthly.join(fedfund, how = 'outer')
bit_monthly = bit_monthly.join(cpi, how = 'outer')

# %%
bit_monthly.plot(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f88484393d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f884844af50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8848439150>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8899265910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8899297f90>],
#       dtype=object)

# %%
bit_monthly.head()
# Out:
#             CBBTCUSD  UNRATE      PCE  FEDFUNDS  CUSR0000SEHE   bit_pct  \
# date
# 2014-12-01    370.00     5.6  12065.0      0.12       295.589       NaN
# 2015-01-01    288.99     5.7  12039.9      0.11       271.328 -0.218946
# 2015-02-01    228.99     5.5  12089.1      0.11       269.641 -0.207620
# 2015-03-01    260.24     5.4  12145.7      0.11       277.899  0.136469
# 2015-04-01    247.87     5.4  12187.4      0.12       266.924 -0.047533
#
#              pce_pct   fed_pct    pi_pct
# date
# 2014-12-01       NaN       NaN       NaN
# 2015-01-01 -0.002080 -0.083333 -0.082077
# 2015-02-01  0.004086  0.000000 -0.006218
# 2015-03-01  0.004682  0.000000  0.030626
# 2015-04-01  0.003433  0.090909 -0.039493

# %%
bit_monthly = bit_monthly.fillna(method = 'bfill')

# %%
bit_monthly['bit_pct'] = bit_monthly['CBBTCUSD'].pct_change()
bit_monthly['unrate_pct'] = bit_monthly['UNRATE'].pct_change()
bit_monthly['pce_pct'] = bit_monthly['PCE'].pct_change()
bit_monthly['fed_pct'] = bit_monthly['FEDFUNDS'].pct_change()
bit_monthly['pi_pct'] = bit_monthly['CUSR0000SEHE'].pct_change()

# %%
sns.pairplot(data = bit_monthly[['bit_pct', 'unrate_pct', 'pce_pct', 'fed_pct','pi_pct']])

# %%
bit_monthly.corr()
# Out:
#               CBBTCUSD    UNRATE       PCE  FEDFUNDS  CUSR0000SEHE   bit_pct  \
# CBBTCUSD      1.000000 -0.808323  0.821256  0.715309      0.671899  0.105557
# UNRATE       -0.808323  1.000000 -0.973603 -0.921581     -0.577140 -0.071360
# PCE           0.821256 -0.973603  1.000000  0.921260      0.616700  0.010670
# FEDFUNDS      0.715309 -0.921581  0.921260  1.000000      0.695904  0.015467
# CUSR0000SEHE  0.671899 -0.577140  0.616700  0.695904      1.000000 -0.119322
# bit_pct       0.105557 -0.071360  0.010670  0.015467     -0.119322  1.000000
# pce_pct      -0.120235 -0.026053 -0.030592  0.093342      0.119094  0.171885
# fed_pct      -0.259316  0.162940 -0.240886 -0.022602     -0.196814  0.163021
# pi_pct        0.101947 -0.155435  0.097691  0.120753      0.128334  0.262051
# unrate_pct    0.112077  0.038613  0.064346 -0.028518     -0.075169 -0.183096
#
#                pce_pct   fed_pct    pi_pct  unrate_pct
# CBBTCUSD     -0.120235 -0.259316  0.101947    0.112077
# UNRATE       -0.026053  0.162940 -0.155435    0.038613
# PCE          -0.030592 -0.240886  0.097691    0.064346
# FEDFUNDS      0.093342 -0.022602  0.120753   -0.028518
# CUSR0000SEHE  0.119094 -0.196814  0.128334   -0.075169
# bit_pct       0.171885  0.163021  0.262051   -0.183096
# pce_pct       1.000000  0.397569  0.488794   -0.774472
# fed_pct       0.397569  1.000000 -0.019257   -0.340242
# pi_pct        0.488794 -0.019257  1.000000   -0.318632
# unrate_pct   -0.774472 -0.340242 -0.318632    1.000000

# %% [markdown]
# Even after reducing the data to percentage change, bitcoin price still display weak to moderate correlation with PCE (personal Expendure Index), Fedfunds, and (PI) Peronal income index and unemployment.

# %%
# save the processed monthly date
bit_monthly.to_csv('bit_monthly.csv')

# %% [markdown]
# ## NASDAQ and SP500

# %%
na = dpf('NASDAQCOM')

# %%
na.head()
# Out:
#             NASDAQCOM
# date
# 2014-12-01    4727.35
# 2014-12-02    4755.81
# 2014-12-03    4774.47
# 2014-12-04    4769.44
# 2014-12-05    4780.76

# %%
na = na.loc['2014-12-01':]

# %%
na.index.min(), na.index.max()
# Out:
# (Timestamp('2014-12-01 00:00:00'), Timestamp('2020-05-01 00:00:00'))

# %%
sp = dpf('SP500')

# %%
sp = sp.loc['2014-12-01':]

# %%
gold = dpf('GOLDAMGBD228NLBM')

# %%
gold.head()
# Out:
#                gold
# date
# 2014-12-01  1178.75
# 2014-12-02  1197.00
# 2014-12-03  1203.25
# 2014-12-04  1204.00
# 2014-12-05  1204.50

# %%
gold.columns = ['gold']
gold = gold.loc['2014-12-01':]

# %%
# Plot these original series on a log scale
plt.figure(figsize = (15, 7))
sns.lineplot(data = np.log(bit))
sns.lineplot(data = np.log(na), palette=['red'])
sns.lineplot(data = np.log(sp), palette=['green'])
sns.lineplot(data = np.log(gold), palette=['yellow'])

# %% [markdown]
# We can get the idea that although these three indexes are very different in terms of magtitude, there re a match in the peaks and valleys, and the upward trends.

# %%
bit_full = bit.join(na, how = 'left')
bit_full = bit_full.join(sp, how = 'left')
bit_full = bit_full.join(gold, how = 'left')

# %%
bit.head()
# Out:
#             CBBTCUSD  NASDAQCOM    SP500     gold   bit_pct    na_pct  \
# date
# 2014-12-01     370.0    4727.35  2053.44  1178.75       NaN       NaN
# 2014-12-02     378.0    4755.81  2066.55  1197.00  0.021622  0.006020
# 2014-12-03     378.0    4774.47  2074.33  1203.25  0.000000  0.003924
# 2014-12-04     377.1    4769.44  2071.92  1204.00 -0.002381 -0.001054
# 2014-12-06     378.0        NaN      NaN      NaN  0.002387  0.000000
#
#               sp_pct  gold_pct
# date
# 2014-12-01       NaN       NaN
# 2014-12-02  0.006384  0.015483
# 2014-12-03  0.003765  0.005221
# 2014-12-04 -0.001162  0.000623
# 2014-12-06  0.000000  0.000000

# %%
bit['bit_pct'] = bit['CBBTCUSD'].pct_change()
bit['na_pct'] = bit['NASDAQCOM'].pct_change()
bit['sp_pct'] = bit['SP500'].pct_change()
bit['gold_pct'] = bit['gold'].pct_change()

# %%
sns.pairplot(data = bit[['bit_pct', 'na_pct', 'sp_pct', 'gold_pct']])
# Out:
# /Users/liwenhuang/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/liwenhuang/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
bit.corr()
# Out:
#            CBBTCUSD  NASDAQCOM     SP500      gold   bit_pct    na_pct  \
# CBBTCUSD   1.000000   0.836581  0.841652  0.606220  0.013689  0.010211
# NASDAQCOM  0.836581   1.000000  0.990247  0.702138  0.006405  0.036081
# SP500      0.841652   0.990247  1.000000  0.679182  0.001138  0.040690
# gold       0.606220   0.702138  0.679182  1.000000  0.003786  0.027237
# bit_pct    0.013689   0.006405  0.001138  0.003786  1.000000  0.101074
# na_pct     0.010211   0.036081  0.040690  0.027237  0.101074  1.000000
# sp_pct     0.007901   0.028242  0.036643  0.013326  0.096681  0.959850
# gold_pct   0.029373   0.019736  0.017454  0.079979  0.053523  0.045846
#
#              sp_pct  gold_pct
# CBBTCUSD   0.007901  0.029373
# NASDAQCOM  0.028242  0.019736
# SP500      0.036643  0.017454
# gold       0.013326  0.079979
# bit_pct    0.096681  0.053523
# na_pct     0.959850  0.045846
# sp_pct     1.000000  0.059387
# gold_pct   0.059387  1.000000

# %% [markdown]
# We would see that although the original time series are highly correlated, but once we take a percentage changes, the correlation reduces drastically.

# %% [markdown]
# reference
#
# https://towardsdatascience.com/going-from-r-to-python-linear-regression-diagnostic-plots-144d1c4aa5a
